# %%
# Core libraries reading the data in both numrical and char
import pandas as pd
import numpy as np

# For Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load materials dataset which is given by usha mam
df1 = pd.read_csv("top10_recommendations.csv")
df2 = pd.read_csv("model_evaluation_metrics.csv")

df1
# Out:
#                   Material_Name  Category  Biodegradable  Predicted_Cost  \
# 0        Reinforced Steel Strap         2              0        1.986816
# 1       Double-Wall Steel Strap         2              0        1.986816
# 2          Recycled Steel Strap         2              0        1.362038
# 3          Standard Steel Strap         2              0        1.484304
# 4        Heavy-Duty Steel Strap         2              0        1.986816
# 5  Commercial-Grade Steel Strap         2              0        1.478779
# 6       Lightweight Steel Strap         2              0        1.507854
# 7         Laminated Steel Strap         2              0        1.983075
# 8        Waterproof Steel Strap         2              0        1.446443
# 9     UV-Stabilized Steel Strap         2              0        2.002829
#
#    Predicted_CO2  Material_Suitability_Score  Final_Rank_Score
# 0       4.795637                  384.822133        378.039680
# 1       2.461310                  375.671636        371.223510
# 2       1.302222                  333.752140        331.087879
# 3       1.982087                  332.162345        328.695954
# 4       2.461310                  332.777541        328.329415
# 5       1.982087                  317.292051        313.831185
# 6       1.690592                  297.028283        293.829837
# 7       2.625716                  284.913490        280.304700
# 8       2.155436                  278.140589        274.538710
# 9       2.301798                  262.186439        257.881812

# %%
df2
# Out:
#                             Model      RMSE       MAE        R2
# 0  Cost Prediction (RandomForest)  1.518805  0.876624  0.449483
# 1        CO2 Prediction (XGBoost)  0.962744  0.471630  0.848573
